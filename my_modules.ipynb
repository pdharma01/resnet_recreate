# %% [markdown]
# <a href="https://colab.research.google.com/github/pdharma01/colab_w_github01/blob/master/function01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
This is my_modules
"""

# %%
def function01(x):
  """
  This is function 1 description.
  """
  print(f"This is function 1 for reload : {x} + 22 = {x+22}")

# %%
def function02(x):
  """
  This is function 2 description.
  """
  print(f"This is function 2 edited : {x} * 100 = {x*100}")

# %%
print("test")
# Out:
# test

# %%
print("test")
print(3 + 5)
# Out:
# test
# 8

# %% [markdown]
# This is a test . Add this to git
