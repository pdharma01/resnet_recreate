# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Import my modules from .ipyb file

# %% [markdown]
# #### Import first time

# %%
import import_ipynb

# %%
# !pip install import-ipynb
import import_ipynb
# Out:
# ...
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp36-none-any.whl size=2976 sha256=071422515e1450b3291935dfcf9ee82569c36062eff5d3a3b6aded0f2e6ef5a7
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# ...

# %%
#Go to folder
# %cd "/content/gdrive/My Drive/GitHub/resnet_recreate"
# Out:
# /content/gdrive/My Drive/GitHub/colab_w_github01

# %%
import load_data

# %% [markdown]
# #### Reload import

# %%
import sys, importlib
# Out:
# importing Jupyter notebook from my_modules.ipynb
# <module 'my_modules' from 'my_modules.ipynb'>

# %%
importlib.reload(sys.modules['my_modules'])
import my_modules
# Out:
# importing Jupyter notebook from my_modules.ipynb

# %% [markdown]
# #### Import from jupyter

# %%
#Go to local foler
# %cd "\Users\pdhar\Google Drive\GitHub\resnet_recreate"
# Out:
# C:\Users\pdhar\Google Drive\GitHub\resnet_recreate

# %%
from importnb import Notebook
with Notebook():
        import load_data

# %%
load_data.function01((3,5))
# Out:
# [3 5]
# Yes it worked!

# %% [markdown]
# ### Reload from jupyter

# %%
from importlib import reload

# %%
with Notebook(): 
    reload(load_data)

# %% [markdown]
# #### Run and explore

# %%
load_data.function01(5) #run an external function
# Out:
# 5
# Yes it worked!

# %%
dir(load_data)
# Out:
# ['__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__test__',
#  'function01',
#  'np']

# %%
help(load_data)
# Out:
# Help on module load_data:
#
# NAME
#     load_data - Load dataset
#
# FUNCTIONS
#     function01(x)
#         This is function 1 description.
#
# DATA
#     __test__ = {'string-24': '# Modules\n', 'string-5': '# Modules\n'}
#
# FILE
#     c:\users\pdhar\google drive\github\resnet_recreate\load_data.ipynb
